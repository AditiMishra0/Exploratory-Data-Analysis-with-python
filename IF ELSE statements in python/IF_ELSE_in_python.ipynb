# %% [markdown]
# #Experiment 6 - Study of conditional statements in python
# ###Aditi Mishra
# ###25070123175
# ###ENTC - A2

# %%
#Problem statement 1 - To check whether an entered number is positive or negetive

num = int(input("Enter a number"))
if num > 0 :
  print("The number is positive")
else :
    print("The number is negetive")
# Out:
# Enter a number-56
# The number is negetive

# %%
#Problem statement 2 - To check whether the number entered is positive, negetive or zero

num = int(input("Enter a number:"))
if num > 0 :
  print("The number is positive:")
elif num < 0 :
    print("The number is negetive:")
else :
    print("The number is zero")
# Out:
# Enter a number:0
# The number is zero

# %%
#Problem statement 3 - To check if the entered number if even or odd

num = int(input("Enter a number:"))
if num % 2 == 0 :
  print("The number is even")
else :
  print("The number is odd")
# Out:
# Enter a number:4576898
# The number is even

# %%
#Problem statement 4 - Find the largest of two numbers

num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))
if num1 > num2 :
  print("The first number is larger among the two")
else:
   print("The second number is larger among the two")
# Out:
# Enter the first number:20
# Enter the second number:23
# The second number is larger among the two

# %%
#Problem statement 5 - Find the largest number among 3 numbers

num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))
num3 = int(input("Enter the third number:"))
if num1 > num2 and num1 > num3 :
  print("The first number is the largest among the three")
elif num2> num1 and num2 > num3 :
  print("The second number is the largest among the three")
else :
  print("The third number is the largest among the three")
# Out:
# Enter the first number:20
# Enter the second number:23
# Enter the third number:21
# The second number is the largest among the three

# %%
#Problem statement 6 - Get input from users for 5 subjects and find average, also calculate grade using if-elif-else

sub1 = int(input("Enter the marks of the first subject:"))
sub2 = int(input("Enter the marks of the second subject:"))
sub3 = int(input("Enter the marks of the third subject:"))
sub4 = int(input("Enter the marks of the fourth subject:"))
sub5 = int(input("Enter the marks of the fifth subject:"))
avg = (sub1+sub2+sub3+sub4+sub5)/5
print("The average score is:",avg)
if avg >= 95 :
  print("Grade A+")
elif avg >= 90 :
  print("Grade A")
elif avg >= 80 :
  print("Grade B+")
elif avg >= 70 :
  print("Grade B")
elif avg >= 60 :
  print("Grade C+")
else :
  print("Fail")
# Out:
# Enter the marks of the first subject:20
# Enter the marks of the second subject:52
# Enter the marks of the third subject:33
# Enter the marks of the fourth subject:10
# Enter the marks of the fifth subject:17
# The average score is: 26.4
# Fail

# %%
#Problem statement 7 - Check whether the entered year is a leap year or not

year = int(input("Enter a year:"))
if (year % 4 == 0) and (year % 100 != 0 or year % 400 == 0) :
  print("The year is a leap year")
else :
  print("The year is not a leap year")
# Out:
# Enter a year:1900
# The year is not a leap year

# %%
#Problem statement 8 - Check if a date is valid and print the incremented date if it is valid

date = input("Enter the date in {dd/mm/yyyy} format:")
dd,mm,yyyy = date.split('/')
dd = int(dd)
mm = int(mm)
yyyy = int(yyyy)
if mm == 1 or mm == 3 or mm == 5 or mm == 7 or mm == 8 or mm == 10 or mm == 12 :
  max_days = 31
elif mm == 4 or mm == 6 or mm == 9 or mm == 11 :
  max_days = 30
elif (yyyy % 4 == 0) and (yyyy % 100 != 0 or yyyy % 400 == 0) :
  max_days = 29
else :
  max_days = 28

if mm < 1 or mm > 12 :
  print("Entered Date is invalid")
elif dd < 1 or dd > max_days :
  print("Entered Date is invalid")

elif dd == max_days and mm != 12 :
  dd = 1
  mm = mm + 1
  print("The incremented date is:",dd,mm,yyyy)
elif dd == 31 and mm == 12 :
  dd = 1
  mm = 1
  yyyy = yyyy + 1
  print("The incremented date is:",dd,mm,yyyy)
else :
  dd = dd + 1
  print("The incremented date is:",dd,mm,yyyy)
# Out:
# Enter the date in {dd/mm/yyyy} format:31/12/1999
# The incremented date is: 1 1 2000

# %%
#Problem: Calculate gross salary of an employee based on basic salary
basic=int(input("enter basic salary:"))
if basic <= 10000:
  print("HRA IS 20% AND DA IS 80%")
  gross_salary=(basic*20/100)+(basic*80/100)
  print("gross salary is:",gross_salary)

elif basic <= 20000:
  print("HRA IS 25% AND DA IS 90%")
  gross_salary1=(basic*25/100)+(basic*90/100)
  print("gross salary is:",gross_salary1)

else:
  print("HRA IS 30% AND DA IS 95%")
  gross_salary2=(basic*30/100)+(basic*95/100)
  print("gross salary is:",gross_salary2)
# Out:
# enter basic salary:50000
# HRA IS 30% AND DA IS 95%
# gross salary is: 62500.0

# %%
#Problem statement 10 - To calculate income tax based on annual income

income = float(input("Enter annual income:"))
if income <= 250000 :
  print("No tax to be given")
elif income <= 500000 :
  print("Tax to be given is 5%")
  tax = (income - 250000)*(5/100)
  print("Tax is:",tax)
elif income <= 1000000 :
  print("Tax to be given is 20%")
  tax1 = (income - 250000)*(20/100)
  print("Tax is:",tax1)
else :
  print("Tax to be given is 30%")
  tax2 = (income - 250000)*(30/100)
  print("Tax is:",tax2)
# Out:
# Enter annual income:300000000
# Tax to be given is 30%
# Tax is: 89925000.0
